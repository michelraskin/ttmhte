# %%
import pandas as pd
import numpy as np
import os
from tqdm import tqdm
import math
import re

import sys
sys.path.append('../../../')
from mount_drive import mount_s_drive

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Model
from sklearn.datasets import make_classification
# Out:
# 2025-04-27 19:16:36.333534: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-04-27 19:16:36.391396: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-04-27 19:16:36.429797: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1745795796.482983     487 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1745795796.493879     487 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-04-27 19:16:36.584879: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
import pandas as pd
import os
import sys
dir1 = os.path.abspath(os.path.join(os.getcwd(), '../../analysisFunctions'))
# dir2 = os.path.abspath(os.path.join(os.getcwd(), '../GANITE'))
sys.path.insert(0, dir1)
# sys.path.insert(0, dir2)
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import statsmodels.api as sm
from statsmodels.formula.api import ols
from statsmodels.stats.multicomp import pairwise_tukeyhsd
from sklearn.feature_selection import VarianceThreshold
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.metrics import accuracy_score, roc_auc_score, make_scorer, auc, roc_curve
from sklearn.model_selection import train_test_split, StratifiedKFold, cross_val_score, GridSearchCV
from xgboost import XGBClassifier, XGBRegressor, plot_tree, plot_importance, to_graphviz
from sklearn.pipeline import Pipeline
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.impute import SimpleImputer
from sklearn.tree import DecisionTreeClassifier, export_graphviz
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from graphviz import Source
from sklearn import tree
from sklearn.svm import SVC, LinearSVC, SVR
import re
from machine_learning import *
# from hyperion_utils import *
# from bartpy.sklearnmodel import SklearnModel
# import doubleml as dml
# import pymc as pm
# import pymc_bart as pmb
from sklearn.neighbors import KNeighborsRegressor
# from pybart.api import BART
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
import statsmodels.api as sm
import statsmodels.formula.api as smf
from scipy.stats import chi2
# from econml.dml import CausalForestDML
# import causalpy as cp
# import pymc_bart as pmb
from sklearn.cluster import KMeans,AgglomerativeClustering, SpectralClustering, MeanShift, DBSCAN 
from scipy.cluster.hierarchy import dendrogram, linkage
import warnings
warnings.filterwarnings('ignore', category=DeprecationWarning)
import random
from stepmix.stepmix import StepMix
from sklearn.metrics import silhouette_score
from mlxtend.feature_selection import SequentialFeatureSelector as SFS
from sklearn.impute import KNNImputer
from PMAPUtil import *
from sklearn.decomposition import PCA

# %%
myTreatmentColumn = 'hypothermia'
myPredictorsDf, X_train, X_test, y_train, y_test = getTrainTestFunctions(aPredictedColumn = 'LastMGCSPositive', 
                                                                         aTreatmentColumn = myTreatmentColumn, 
                                                                         aSkipTemp = True)

# %%
def getCovariatePreprocessor(aKeepColumns):
    return    ColumnTransformer(
            transformers=[
                ('keep', 'passthrough', aKeepColumns), 
            ],
            remainder = PCA(0.99)
        )

def getVariancePreprocessor(aKeepColumns):
    return    ColumnTransformer(
            transformers=[
                ('keep', 'passthrough', aKeepColumns), 
            ],
            remainder = VarianceThreshold(0.01)
        )

# %%
def getDefaultPipelineSteps(X_train):
    myNumericalColumns = X_train.columns[(X_train.nunique() > 5) & (X_train.dtypes != object)]
    myBinaryColumns = X_train.columns[X_train.nunique() == 2]
    myPreprocessor = getDefaultPreprocessor(aNumericalColumns=myNumericalColumns, aBinaryColumns=myBinaryColumns)
    myPreprocessor.set_output(transform="pandas")
    myImputer = KNNImputer(n_neighbors=50)
    myImputer.set_output(transform="pandas")
    myBinaryColumns  = ['bin__' + x for x in myBinaryColumns]
    myCovariates = getCovariatePreprocessor(['keep__bin__' + myTreatmentColumn])
    myCovariates.set_output(transform="pandas")
    myVariance = getVariancePreprocessor(['bin__' + myTreatmentColumn])
    myVariance.set_output(transform="pandas")
    return [('preprocessor', myPreprocessor),  ('variance', myVariance), ('imputer', myImputer), ('covariates', myCovariates)]

# %%
X_train = X_train.loc[:, X_train.isnull().mean() < 0.9]
X_test = X_test[X_train.columns]

# %%
myPipeline = Pipeline(getDefaultPipelineSteps(X_train))
X_train_transf = myPipeline.fit_transform(X_train, y_train)
X_test_transf = myPipeline.transform(X_test)
X_train_transf = pd.DataFrame(X_train_transf, columns = myPipeline.get_feature_names_out())
X_test_transf = pd.DataFrame(X_test_transf, columns = myPipeline.get_feature_names_out())

# %%
X_test_transf.columns
# Out:
# Index(['keep__keep__bin__hypothermia', 'remainder__pca0', 'remainder__pca1',
#        'remainder__pca2', 'remainder__pca3', 'remainder__pca4',
#        'remainder__pca5', 'remainder__pca6', 'remainder__pca7',
#        'remainder__pca8',
#        ...
#        'remainder__pca629', 'remainder__pca630', 'remainder__pca631',
#        'remainder__pca632', 'remainder__pca633', 'remainder__pca634',
#        'remainder__pca635', 'remainder__pca636', 'remainder__pca637',
#        'remainder__pca638'],
#       dtype='object', length=640)

# %%
model = keras.Sequential([
    keras.Input(shape=(X_train_transf.shape[1],)),  
    layers.Dense(16, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(1, activation='sigmoid') 
])
# from tensorflow.keras.callbacks import EarlyStopping

# early_stopping = EarlyStopping(
#     monitor='loss',  # Metric to track
#     patience=10,          # Number of epochs to wait before stopping
#     restore_best_weights=True  # Restore the best model weights
# )

model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy', tf.keras.metrics.AUC(name="roc_auc")])

# %%
history = model.fit(X_train_transf, y_train.reset_index().drop(columns='index'), epochs=15, batch_size=8, validation_data=(X_test_transf, y_test.reset_index().drop(columns='index')))#, callbacks=[early_stopping])
# Out:
# Epoch 1/15
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5923 - loss: 0.8699 - roc_auc: 0.4509 - val_accuracy: 0.7474 - val_loss: 0.5548 - val_roc_auc: 0.6396
# Epoch 2/15
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7545 - loss: 0.5295 - roc_auc: 0.7145 - val_accuracy: 0.7809 - val_loss: 0.4960 - val_roc_auc: 0.7541
# Epoch 3/15
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7993 - loss: 0.4451 - roc_auc: 0.8064 - val_accuracy: 0.7938 - val_loss: 0.4663 - val_roc_auc: 0.7960
# Epoch 4/15
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8559 - loss: 0.3519 - roc_auc: 0.8952 - val_accuracy: 0.8041 - val_loss: 0.4495 - val_roc_auc: 0.8137
# Epoch 5/15
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8718 - loss: 0.2956 - roc_auc: 0.9373 - val_accuracy: 0.8170 - val_loss: 0.4464 - val_roc_auc: 0.8148
# Epoch 6/15
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8885 - loss: 0.2642 - roc_auc: 0.9527 - val_accuracy: 0.8067 - val_loss: 0.4415 - val_roc_auc: 0.8200
# Epoch 7/15
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9131 - loss: 0.2151 - roc_auc: 0.9759 - val_accuracy: 0.8093 - val_loss: 0.4501 - val_roc_auc: 0.8251
# Epoch 8/15
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9246 - loss: 0.1804 - roc_auc: 0.9799 - val_accuracy: 0.8093 - val_loss: 0.4619 - val_roc_auc: 0.8265
# Epoch 9/15
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9394 - loss: 0.1634 - roc_auc: 0.9901 - val_accuracy: 0.8170 - val_loss: 0.4730 - val_roc_auc: 0.8298
# Epoch 10/15
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9379 - loss: 0.1460 - roc_auc: 0.9914 - val_accuracy: 0.8196 - val_loss: 0.4753 - val_roc_auc: 0.8289
# Epoch 11/15
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9483 - loss: 0.1126 - roc_auc: 0.9945 - val_accuracy: 0.8119 - val_loss: 0.4770 - val_roc_auc: 0.8325
# Epoch 12/15
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9690 - loss: 0.0984 - roc_auc: 0.9962 - val_accuracy: 0.8170 - val_loss: 0.4950 - val_roc_auc: 0.8322
# Epoch 13/15
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9401 - loss: 0.1229 - roc_auc: 0.9924 - val_accuracy: 0.8119 - val_loss: 0.5153 - val_roc_auc: 0.8289
# Epoch 14/15
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9597 - loss: 0.1091 - roc_auc: 0.9954 - val_accuracy: 0.8170 - val_loss: 0.5306 - val_roc_auc: 0.8345
# Epoch 15/15
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9566 - loss: 0.0948 - roc_auc: 0.9971 - val_accuracy: 0.8196 - val_loss: 0.5396 - val_roc_auc: 0.8331

# %%
# Extract loss values
train_loss = history.history['roc_auc']
val_loss = history.history['val_roc_auc']

# Plot training & validation loss
plt.plot(train_loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss', linestyle='dashed')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training vs Validation ROC AUC Over Time')
plt.legend()
plt.grid(True)
plt.show()

# %%
y_pred_probs = model.predict(X_test_transf)  # Probabilities

# Compute ROC AUC
roc_auc = roc_auc_score(y_test, y_pred_probs)
print(f"ROC AUC Score: {roc_auc:.4f}")
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# ROC AUC Score: 0.7718

# %%
import numpy as np
from sklearn.metrics import roc_auc_score

def bootstrap_auc_ci(y_true, y_pred_proba, n_bootstraps=1000, ci=95, random_seed=42):
    rng = np.random.RandomState(random_seed)
    n = len(y_true)
    bootstrapped_scores = []
    
    for _ in range(n_bootstraps):
        # Sample with replacement
        indices = rng.choice(np.arange(n), size=n, replace=True)
        if len(np.unique(y_true[indices])) < 2:
            # We need at least one positive and one negative sample
            continue
        score = roc_auc_score(y_true[indices], y_pred_proba[indices])
        bootstrapped_scores.append(score)
    
    sorted_scores = np.sort(bootstrapped_scores)
    lower_bound = np.percentile(sorted_scores, (100 - ci) / 2)
    upper_bound = np.percentile(sorted_scores, 100 - (100 - ci) / 2)
    
    return lower_bound, upper_bound, sorted_scores

# Example usage
# y_true = np.array([...])
# y_pred_proba = np.array([...])

ci_lower, ci_upper, auc_scores = bootstrap_auc_ci(y_test.to_numpy(), y_pred_probs)
print(f"95% CI for AUC: [{ci_lower:.3f}, {ci_upper:.3f}]")
# Out:
# 95% CI for AUC: [0.723, 0.820]

# %%
myX = pd.concat([X_train_transf.reset_index().drop(columns='index'), X_test_transf.reset_index().drop(columns='index')])
myY = pd.concat([y_train.reset_index().drop(columns='index'), y_test.reset_index().drop(columns='index')])

# %%
getTreatmentEffectDiff(aX = myX.reset_index().drop(columns='index'), aY = myY.reset_index().drop(columns='index'), aModel = model, \
                       aCategory = 'LastMGCSPositive', aGroup = 'keep__keep__bin__hypothermia', aUseNeuralNetwork = True, aByGroup = False)
# Out:
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 869us/step
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 832us/step
# Optimization terminated successfully.
#          Current function value: 0.548737
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.548657
#          Iterations 5
# Likelihood ratio of test results:
# Chi square statistic: 0.20742556729328498
# p-value: 0.6487927445743322
# Degress of freedom: 1.0
# No interaction                            Logit Regression Results
# ==============================================================================
# Dep. Variable:       LastMGCSPositive   No. Observations:                 1292
# Model:                          Logit   Df Residuals:                     1289
# Method:                           MLE   Df Model:                            2
# Date:                Mon, 28 Apr 2025   Pseudo R-squ.:                 0.01360
# Time:                        08:01:21   Log-Likelihood:                -708.97
# converged:                       True   LL-Null:                       -718.75
# Covariance Type:            nonrobust   LLR p-value:                 5.677e-05
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept           -0.8958      0.093     -9.618      0.000      -1.078      -0.713
# predicted_effect    -0.2714      1.552     -0.175      0.861      -3.313       2.770
# TreatmentColumn     -0.5873      0.135     -4.349      0.000      -0.852      -0.323
# ====================================================================================
# Interaction                            Logit Regression Results
# ==============================================================================
# Dep. Variable:       LastMGCSPositive   No. Observations:                 1292
# Model:                          Logit   Df Residuals:                     1288
# Method:                           MLE   Df Model:                            3
# Date:                Mon, 28 Apr 2025   Pseudo R-squ.:                 0.01375
# Time:                        08:01:21   Log-Likelihood:                -708.86
# converged:                       True   LL-Null:                       -718.75
# Covariance Type:            nonrobust   LLR p-value:                 0.0001903
# ====================================================================================================
#                                        coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Intercept                           -0.8798      0.099     -8.855      0.000      -1.075      -0.685
# predicted_effect                     0.2993      2.006      0.149      0.881      -3.632       4.230
# TreatmentColumn                     -0.6278      0.162     -3.878      0.000      -0.945      -0.311
# predicted_effect:TreatmentColumn    -1.4388      3.147     -0.457      0.648      -7.607       4.730
# ====================================================================================================
# 0.6487927445743322

# %%
getTreatmentEffectDiff(aX = X_train_transf.reset_index().drop(columns='index'), aY = y_train.reset_index().drop(columns='index'), aModel = model, \
                       aCategory = 'death_at_disch', aGroup = 'keep__keep__bin__hypothermia', aUseNeuralNetwork = True, aByGroup = False)
# Out:
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 977us/step
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 930us/step
# Optimization terminated successfully.
#          Current function value: 0.638320
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.638105
#          Iterations 5
# Likelihood ratio of test results:
# Chi square statistic: 0.42508536441914657
# p-value: 0.5144103917844376
# Degress of freedom: 1.0
# No interaction                            Logit Regression Results
# ==============================================================================
# Dep. Variable:         death_at_disch   No. Observations:                  991
# Model:                          Logit   Df Residuals:                      988
# Method:                           MLE   Df Model:                            2
# Date:                Mon, 28 Apr 2025   Pseudo R-squ.:                0.004299
# Time:                        08:04:36   Log-Likelihood:                -632.57
# converged:                       True   LL-Null:                       -635.31
# Covariance Type:            nonrobust   LLR p-value:                   0.06516
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept            0.5329      0.097      5.483      0.000       0.342       0.723
# predicted_effect     0.2864      3.890      0.074      0.941      -7.338       7.911
# TreatmentColumn      0.3217      0.138      2.323      0.020       0.050       0.593
# ====================================================================================
# Interaction                            Logit Regression Results
# ==============================================================================
# Dep. Variable:         death_at_disch   No. Observations:                  991
# Model:                          Logit   Df Residuals:                      987
# Method:                           MLE   Df Model:                            3
# Date:                Mon, 28 Apr 2025   Pseudo R-squ.:                0.004633
# Time:                        08:04:36   Log-Likelihood:                -632.36
# converged:                       True   LL-Null:                       -635.31
# Covariance Type:            nonrobust   LLR p-value:                    0.1172
# ====================================================================================================
#                                        coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Intercept                            0.5556      0.103      5.373      0.000       0.353       0.758
# predicted_effect                    -1.6078      4.835     -0.333      0.739     -11.084       7.869
# TreatmentColumn                      0.2592      0.168      1.539      0.124      -0.071       0.589
# predicted_effect:TreatmentColumn     5.3508      8.288      0.646      0.519     -10.894      21.596
# ====================================================================================================
# 0.5144103917844376
